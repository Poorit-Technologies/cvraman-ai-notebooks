# %% [markdown]
# # Exercise: Brochure Generator
#
# Build a Gradio app that scrapes a company's landing page and uses an LLM to generate a marketing brochure.
#
# **You will:**
# 1. Install dependencies
# 2. Set up imports and API key
# 3. Use a provided web scraping function
# 4. Write a system prompt
# 5. Write a streaming LLM function
# 6. Wire it up with a Gradio UI

# %%
# Step 1: Install the packages you'll need
# litellm, gradio, requests, beautifulsoup4

# %%
# Step 2: Import os, getpass, gradio, requests, BeautifulSoup, and litellm's completion
# Then set OPENAI_API_KEY using getpass() so your key stays hidden

# %%
# Step 3: Web scraping utility (provided — just run this cell)

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}


def fetch_website_contents(url):
    """
    Return the title and contents of the website at the given url;
    truncate to 2,000 characters as a sensible limit
    """
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    title = soup.title.string if soup.title else "No title found"
    if soup.body:
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        text = soup.body.get_text(separator="\n", strip=True)
    else:
        text = ""
    return (title + "\n\n" + text)[:2_000]

# %%
# Step 4: Write a system_message string that tells the LLM to:
# - Analyze a company's landing page
# - Create a short brochure for customers, investors, and recruits
# - Respond in markdown without code blocks

# %%
# Step 5: Write stream_brochure(company_name, url) that:
# - Builds a prompt using company_name and fetch_website_contents(url)
# - Calls completion() with model="gpt-4o-mini", stream=True
# - Yields accumulated text from each chunk (for Gradio streaming)

# %%
# Step 6: Create a gr.Interface that:
# - Takes company name (Textbox) and URL (Textbox) as inputs
# - Outputs to a gr.Markdown component
# - Has a couple of examples, e.g. ["Anthropic", "https://anthropic.com"]
# Then call .launch()
